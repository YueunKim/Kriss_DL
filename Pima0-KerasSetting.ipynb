# %%
import keras as kr

# %%
print(kr.__version__)
# Out:
# 2.4.3

# %%
print(kr.backend.backend())
# Out:
# tensorflow

# %%
import tensorflow as tf

# %%
print(tf.__version__)
# Out:
# 2.3.0

# %%
# !pip install keras

# %%
# !ls
# Out:
# sample_data

# %%
# !ls -la
# Out:
# total 16
# drwxr-xr-x 1 root root 4096 Sep 11 16:28 .
# drwxr-xr-x 1 root root 4096 Sep 15 06:24 ..
# drwxr-xr-x 1 root root 4096 Sep 11 16:28 .config
# drwxr-xr-x 1 root root 4096 Sep 11 16:28 sample_data
